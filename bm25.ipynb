# %%
import os
import pandas as pd

from tqdm.auto import tqdm
from haystack_integrations.document_stores.elasticsearch import ElasticsearchDocumentStore
from haystack.components.embedders import SentenceTransformersTextEmbedder
from haystack_integrations.components.retrievers.elasticsearch import ElasticsearchBM25Retriever
from haystack import Document
from haystack import Pipeline

# %%
dataset_path = 'datasets/allegro/'

embedder_model = "sentence-transformers/multi-qa-mpnet-base-dot-v1"

# %% [markdown]
# ## Lauch ElasticSearch in Docker

# %%
# Run docker-compose up while in main directory in order to launch elasticsearch instance.

# %%
document_store = ElasticsearchDocumentStore(hosts='http://localhost:9200')
document_store.delete_documents(document_ids=[document.id for document in document_store.filter_documents(filters={})])

# %% [markdown]
# ## Index Passages

# %%
passages = pd.read_json(os.path.join(dataset_path, 'passages.jl'), lines=True, chunksize=int(1e6))

for batch in tqdm(passages):
    if 'title' in batch:
        batch['title'] = batch['title'].fillna('')
        batch['text'] = batch.apply(lambda r: r['title'] + ' ' + r['text'], axis=1)
    
    batch = batch.rename(columns={'id': 'passage-id', 'text': 'content'})
    batch_as_dicts = batch.to_dict(orient='records')
    document_store.write_documents([Document(content=passageDict['content'], id=passageDict['passage-id']) for passageDict in batch_as_dicts])
# Out:
# 0it [00:00, ?it/s]

# %%
document_store.count_documents()
# Out:
# 921

# %% [markdown]
# ## Retrieve Similar Passages

# %%
# Use a retriever that utilizes BM25 algorithm (bag-of-words based)
retriever = ElasticsearchBM25Retriever(document_store=document_store)

pipe = Pipeline()
pipe.add_component("retriever", retriever)

# %%
questions = pd.read_json(os.path.join(dataset_path, 'questions-test.jl'), lines=True)
questions.shape
# Out:
# (900, 2)

# %%
preds = []

for _, row in tqdm(questions.iterrows()):
    top_passages = pipe.run({"retriever": {"query": row['text']}})
    
    print(top_passages)
    
    for passage in top_passages['retriever']['documents']:
        passage = passage.to_dict()
        preds.append({
            'question-id': row['id'],
            'passage-id': passage['id'],
            'score': passage['score'],
        })

preds = pd.DataFrame(preds)
# Out:
# 0it [00:00, ?it/s]
# {'retriever': {'documents': [Document(id=821, content: 'Dodatkowa prowizja od sprzedaży w wyróżnionych ofertach obowiązuje w kategoriach objętych standardow...', score: 45.881447), Document(id=685, content: 'Naliczamy każdorazowo w chwili sprzedaży, podobnie jak w przypadku standardowej prowizji od sprzedaż...', score: 30.520634), Document(id=6, content: 'Dodatkową prowizję od sprzedaży w wyróżnionych ofertach naliczamy we wszystkich ofertach z aktywną o...', score: 25.895947), Document(id=218, content: 'Dodatkową prowizję zwrócimy Ci na takich samych zasadach, jak standardową prowizję od sprzedaży.', score: 20.520496), Document(id=379, content: 'Tak, dodatkowa prowizja obowiązuje konta zwykłe oraz konta Firma.', score: 18.640553), Document(id=509, content: 'Wysokość prowizji od sprzedaży nie jest jednakowa dla wszystkich ofert. Zależy od
# * ceny końcowej, z...', score: 17.054335), Document(id=388, content: 'Pobieramy następujące opłaty:
# * za wystawienie przedmiotu,
# * prowizję od sprzedaży,
# * za ewentualne ...', score: 12.813876), Document(id=875, content: 'Prowizji od sprzedaży nie naliczamy w kategoriach ogłoszeniowych (Samochody, Motocykle i quady; Używ...', score: 12.69612), Document(id=763, content: 'Ten sposób oznaczania ofert dedykujemy tylko stałym i aktywnym Partnerom Strefy okazji. Do końca 201...', score: 12.598778), Document(id=869, content: 'Z każdą pozytywną weryfikacją lub przedłużeniem statusu Super Sprzedawcy o kolejne 30 dni, przyznamy...', score: 12.513844)]}}
# {'retriever': {'documents': [Document(id=822, content: 'Tak. Jeśli wystawisz Sprzedającemu ocenę dotyczącą transakcji, może on na nią odpowiedzieć (ma na to...', score: 25.84436), Document(id=502, content: 'Kupujący odpowiada za treść komentarza wystawionego Sprzedającemu. Możesz jednak wspólnie ze Sprzeda...', score: 18.345121), Document(id=765, content: 'Za treść komentarza odpowiedzialny jest Kupujący. Możesz jednak wspólnie z Kupującym zdecydować o us...', score: 17.786583), Document(id=223, content: '1. Przejdź do zakładki Otrzymane oceny.
# 2. Wybierz odpowiednią ocenę spośród nie polecam i rozwiń je...', score: 15.566123), Document(id=450, content: 'Klikając [kup teraz] lub wygrywając licytację, zawierasz ze Sprzedającym umowę, czyli zobowiązujesz ...', score: 12.792986), Document(id=782, content: 'Zakładka Moje konto
# Zebraliśmy w niej informacje o Twoim koncie na Allegro, czyli wpisane przez Cieb...', score: 11.435586), Document(id=280, content: 'Jeśli Kupujący rozpoczął z Tobą Dyskusję
# * masz obowiązek udzielenia odpowiedzi Kupującemu w ciągu 2...', score: 10.483493), Document(id=409, content: 'Jeśli masz konto firmowe i spełniasz poniższe warunki, możesz zostać Super Sprzedawcą:
# *  Zrealizowa...', score: 10.275259), Document(id=468, content: 'W Dyskusji ze Sprzedającym:
# * powinien on odpowiedzieć Ci w ciągu 24 godzin,
# * jeśli nie uda Wam się...', score: 10.116194), Document(id=684, content: 'Decyzja o przyznaniu rat zależy od tego, w jaki sposób instytucja przyznająca raty oceni Twoją zdoln...', score: 10.091316)]}}
# {'retriever': {'documents': [Document(id=877, content: 'Twoje wybrane oferty możesz wyróżnić Monetami - jest to bezpłatne. Opłatę za Monety naliczymy dopier...', score: 23.241007), Document(id=439, content: 'W zakładce Super Sprzedawca możesz sprawdzić, czy spełniasz warunki przyjęcia do programu. Jeśli tak...', score: 15.30558), Document(id=488, content: 'Tak, pakiet darmowych wyróżnień obniża jedynie koszt stały wystawienia oferty wyróżnionej.', score: 11.496101), Document(id=640, content: 'Aby oznaczyć ofertę:
# * przejdź do zakładki Moje oferty
# * wybierz ofertę, którą chcesz oznaczyć
# * prz...', score: 11.35182), Document(id=103, content: 'Tak, zawsze możesz spłacić swoje zobowiązanie przed terminem. Wcześniejsza spłata nie wiąże się z ża...', score: 10.425927), Document(id=622, content: 'Tym oznaczeniem wyróżnisz swoje najbardziej popularne oferty i zwiększasz ich widoczność na liście o...', score: 10.398202), Document(id=630, content: 'Jeśli chcesz promować Twoje oferty i przyciągnąć do nich więcej Kupujących, masz do dyspozycji Wyróż...', score: 10.246988), Document(id=551, content: 'Możesz wybrać dowolne oferty, które będziesz promować Monetami:
# 1. przejdź do zakładki Monety
# 2. kli...', score: 10.024097), Document(id=868, content: 'Jeśli chcesz, żeby Twoje oferty zdobywały coraz więcej wyświetleń i kliknięć, sugerujemy zawsze upew...', score: 9.595682), Document(id=197, content: 'Tak. Jeśli wystawiasz ponownie ofertę, to tworzysz nową ofertę (nowy numer oferty), dlatego traktuje...', score: 9.120539)]}}
# {'retriever': {'documents': [Document(id=730, content: 'Cykliczne naliczanie opłat co 10 dni pozwala Ci łatwiej zarządzać promowaniem w trwających ofertach,...', score: 11.848003), Document(id=574, content: 'Wyłącz promowanie przed zakończeniem bieżącego cyklu promowania. Zrobisz to przez edycję oferty. Wte...', score: 10.740753), Document(id=309, content: 'Wyłącz promowanie przed zakończeniem bieżącego cyklu promowania. Zrobisz to poprzez edycję oferty w ...', score: 10.156384), Document(id=580, content: 'Każdy etap Dyskusji oznaczamy odpowiednimi statusami:
# * W toku - każda rozpoczęta Dyskusja między 1 ...', score: 9.182717), Document(id=630, content: 'Jeśli chcesz promować Twoje oferty i przyciągnąć do nich więcej Kupujących, masz do dyspozycji Wyróż...', score: 9.067676), Document(id=758, content: 'Ogłoszenie można wystawić na czas nieokreślony lub na 10, 20, 30 dni. Opłaty naliczamy co 10 dni.
# C...', score: 8.733593), Document(id=6, content: 'Dodatkową prowizję od sprzedaży w wyróżnionych ofertach naliczamy we wszystkich ofertach z aktywną o...', score: 8.11918), Document(id=149, content: 'Celem miniaturek jest jak najlepsze zaprezentowanie sprzedawanego przedmiotu Klientowi. Zdjęcia prod...', score: 7.9454017), Document(id=799, content: 'Allegro Ads są rozliczane w modelu, w którym płacisz nie za wyświetlenie, a jedynie za kliknięcie re...', score: 7.13227), Document(id=120, content: 'Bieżące saldo Twojego konta sprawdzisz w zakładce Bieżące saldo i wpłata.
# Jeśli Twoje saldo będzie u...', score: 6.740827)]}}
# {'retriever': {'documents': [Document(id=903, content: 'Jeśli konsument kupi przedmiot od przedsiębiorcy, wówczas to przedsiębiorca, czyli Sprzedający odpow...', score: 21.661184), Document(id=750, content: 'Leasing jest prostą formą finansowania zakupów przedsiębiorców. Leasingodawca kupuje przedmiot wskaz...', score: 15.040281), Document(id=501, content: 'W sytuacji, gdy otrzymany przez Kupującego towar posiada wadę i ujawni się ona w ciągu 2 lat od dost...', score: 13.626802), Document(id=664, content: 'Program Ochrony Kupujących pomaga Kupującym, którzy napotkali problemy po zakupie.
# Program zapewnia ...', score: 12.567514), Document(id=698, content: 'Jeśli uznasz reklamację wynikającą z rękojmi, pokrywasz koszty przesyłki. Jeśli Kupujący sam zapłaci...', score: 11.312399), Document(id=791, content: 'Program Ochrony Kupujących pomoże Ci, jeśli napotkasz problemy po zakupie na Allegro.
# Program zapewn...', score: 11.127593), Document(id=671, content: 'W sytuacji, gdy otrzymany przez Ciebie przedmiot posiada wadę i ujawni się ona w ciągu 2 lat od jego...', score: 10.861242), Document(id=841, content: 'Tak, zwrócimy Ci prowizję w formie rabatu transakcyjnego jeśli nie doszło do zrealizowania umowy z o...', score: 10.454008), Document(id=469, content: 'Kupujący w Allegro lubią śledzić swoje zamówienia. 89% z nich deklaruje, że powiadomienie o statusie...', score: 10.279015), Document(id=599, content: 'Konto zwykłe
# Zarejestruj konto zwykłe, jeżeli działasz jako osoba prywatna. Możesz wpisać w ustawien...', score: 9.755694)]}}
# {'retriever': {'documents': [Document(id=649, content: 'Spłaty rat wykonasz na rachunek bankowy, który znajdziesz w Zestawieniu transakcji. Pamiętaj, że ban...', score: 15.2280655), Document(id=103, content: 'Tak, zawsze możesz spłacić swoje zobowiązanie przed terminem. Wcześniejsza spłata nie wiąże się z ża...', score: 14.390813), Document(id=368, content: 'Pamiętaj, że w ramach Rat Od.nowa można wielokrotnie korzystać z przyznanych przez bank środków. Każ...', score: 12.926456), Document(id=768, content: '1. Kliknij [kup bez konta].
# 2. Wybierz metodę dostawy.
# 3. Uzupełnij dane potrzebne do wysyłki. Podaj...', score: 9.539983), Document(id=348, content: 'Ubezpieczenie a zakup na raty
# Samej składki ubezpieczeniowej nie możesz rozłożyć na raty, ponieważ z...', score: 9.171648), Document(id=401, content: 'Tak, rachunki za usługi Allegro możesz opłacić kartą.
# Aby to zrobić
# 1. Przejdź do zakładki Bieżące s...', score: 9.015262), Document(id=335, content: 'Aktualny regulamin rat ZERO znajdziesz pod adresem https://na.allegro.pl/raty.', score: 8.671999), Document(id=383, content: 'Masz do wyboru dwa rodzaje zakupów na raty:
# * Raty ZERO - w ratach ZERO płacisz tylko za towar. Nie ...', score: 8.57959), Document(id=89, content: 'Po spłacie zakupu Twój limit na zakupy na Raty Od.nowa na Allegro będzie ponownie w całości do Twoje...', score: 8.519483), Document(id=3, content: 'Raty Od.nowa to sposób płatności za zakupy na Allegro w ratach, w ramach odnawialnego limitu kredyto...', score: 7.7032337)]}}
# {'retriever': {'documents': [Document(id=283, content: 'Dla Ciebie oznacza to bardziej efektywne wykorzystanie budżetu. Zazwyczaj wahania nie są duże - maks...', score: 33.432858), Document(id=34, content: 'Budżet dzienny to kwota dziennych wydatków reklamowych. Wartość dziennego budżetu ustawiasz w panelu...', score: 24.24385), Document(id=130, content: 'PayU S.A. z siedzibą w Poznaniu jest podmiotem pośredniczącym pomiędzy pożyczkobiorcą a partnerem po...', score: 10.2927685), Document(id=853, content: 'Licytacja to aukcja, w której decydujesz jaką kwotę maksymalnie chcesz przeznaczyć na interesujący C...', score: 9.690164), Document(id=788, content: 'Kiedy reklamujesz się w Allegro Ads samodzielnie decydujesz, jaki budżet chcesz przeznaczyć na rekla...', score: 9.671457), Document(id=724, content: 'Liczbę przedmiotów, które masz już w koszyku, możesz zwiększać. Kliknij ponownie w przycisk [dodaj d...', score: 8.505836), Document(id=681, content: 'Minimalna kwota pożyczki to 300 zł, a maksymalna kwota to 20 000 zł.', score: 8.219974), Document(id=319, content: 'Poziom ceny za jedno kliknięcie określa Max CPC (Cost Per Click), czyli maksymalna stawka, jaką jest...', score: 8.200521), Document(id=537, content: 'Czas, który mija od momentu wykonania wpłaty do jej zaksięgowania na naszym koncie, jest uzależniony...', score: 8.15685), Document(id=136, content: '* Zapłacisz tylko za kliknięcie w reklamowaną przez siebie ofertę, a więc za potencjalnego klienta.
# ...', score: 7.9974046)]}}
# {'retriever': {'documents': [Document(id=192, content: 'Prowizję naliczamy za każdy przedmiot składający się na zestaw. Jeśli zestaw sprzedajesz z rabatem, ...', score: 21.401585), Document(id=915, content: '1. Zaplanuj wystawianie przedmiotów tak, aby ostatnie z Twoich ofert kończyły się kilka dni przed za...', score: 20.73528), Document(id=685, content: 'Naliczamy każdorazowo w chwili sprzedaży, podobnie jak w przypadku standardowej prowizji od sprzedaż...', score: 20.667854), Document(id=509, content: 'Wysokość prowizji od sprzedaży nie jest jednakowa dla wszystkich ofert. Zależy od
# * ceny końcowej, z...', score: 17.920668), Document(id=821, content: 'Dodatkowa prowizja od sprzedaży w wyróżnionych ofertach obowiązuje w kategoriach objętych standardow...', score: 16.681797), Document(id=218, content: 'Dodatkową prowizję zwrócimy Ci na takich samych zasadach, jak standardową prowizję od sprzedaży.', score: 14.634359), Document(id=631, content: 'To oznaczenie informuje kupujących, że oferujesz rabat przy zakupie kilku sztuk przedmiotu lub obniż...', score: 14.101434), Document(id=194, content: 'Cena minimalna, która występuje w niektórych licytacjach, to najniższa kwota, za jaką Sprzedający zg...', score: 13.532279), Document(id=234, content: 'Sposób oznaczenia zestawu na stronie oferty zależy od wysokości rabatu, jaki sprzedający udziela na ...', score: 13.335246), Document(id=352, content: 'Sposób oznaczenia zestawu na stronie oferty zależy od wysokości rabatu, jaki udzielasz na dany zesta...', score: 13.335246)]}}
# {'retriever': {'documents': [Document(id=90, content: 'Gdy sortujemy oferty w ten sposób, bierzemy pod uwagę wiele czynników. Możemy je podzielić na:
# Dane ...', score: 14.723607), Document(id=232, content: 'To proste:
# 1. Wypełnij formularz sprzedaży i wystaw jedną ofertę.
# 2. Przejdź do strony Moje oferty i...', score: 13.92133), Document(id=545, content: 'Uzupełniamy te dane, które na ten moment mamy dostępne dla wybranego przedmiotu. Pozostałe parametry...', score: 13.681545), Document(id=907, content: '* Im czytelniejsza będzie twoja oferta, tym więcej klientów będzie nią zainteresowanych. Im więcej k...', score: 13.350777), Document(id=31, content: 'Oferta będzie widoczna w niezmienionej formie do momentu jej planowanego zakończenia. Jeśli chcesz j...', score: 13.304009), Document(id=225, content: 'Oferty połączysz w zakładce Wielowariantowość:
# 1. Kliknij przycisk [dodaj].
# 2. Wpisz frazę, na podst...', score: 12.860517), Document(id=868, content: 'Jeśli chcesz, żeby Twoje oferty zdobywały coraz więcej wyświetleń i kliknięć, sugerujemy zawsze upew...', score: 12.6388), Document(id=897, content: 'Automatyczne uzupełnianie parametrów dostępne jest podczas wystawiania nowej oferty i przy skorzysta...', score: 12.620382), Document(id=530, content: 'Jeśli nikt nie kupił Twojego przedmiotu, możesz go ponownie wystawić. W zakładce Moje oferty zaznacz...', score: 12.016036), Document(id=16, content: '1. Zaloguj się do konta i kliknij [wystaw przedmiot]. Przeniesiemy Cię do formularza sprzedaży.
# 2. W...', score: 11.762901)]}}
# {'retriever': {'documents': [Document(id=734, content: '1. Przejdź do zakładki Dane konta Allegro.
# 2. W polu konto Konto Firma kliknij odnośnik [Przejdź do ...', score: 20.464048), Document(id=46, content: '1. Dane do faktur zmienisz w zakładce Dane konta Allegro. Zmiana danych w ustawieniach konta Allegro...', score: 20.327402), Document(id=63, content: 'Aby otworzyć konto fakturowe:
# 1. przejdź do zakładki Faktury,
# 2. wybierz formularz danych do faktury...', score: 17.485691), Document(id=208, content: 'Nie możemy wystawić faktur za usługi wcześniejsze, niż z miesiąca w którym aktywujesz konto fakturow...', score: 17.025833), Document(id=550, content: '1. W zakładce Dane konta Allegro wpisz nazwę swojej firmy i numer NIP oraz załącz skany dokumentów r...', score: 17.004385), Document(id=538, content: 'Wystawiamy faktury wyłącznie nabywcom usług serwisu, czyli podmiotom, które zarejestrowały konto w s...', score: 16.654547), Document(id=432, content: '1. Uzupełnij swoje dane w zakładce Faktury.
# 2. Jeżeli chcesz otrzymywać faktury na inny adres, niż t...', score: 16.588268), Document(id=866, content: '1. Swoje dane zmienisz w zakładce Faktury.
# 2. Jeżeli chcesz otrzymywać faktury na inny adres, niż te...', score: 16.588268), Document(id=122, content: 'Zmiana danych do faktur jest tożsama ze zmianą danych na koncie Allegro. Dlatego jeśli chcesz pobier...', score: 16.348736), Document(id=79, content: 'Faktury za dany miesiąc obejmują należności naliczone w tym miesiącu. Wystawiamy je nie później, niż...', score: 15.348348)]}}
# {'retriever': {'documents': [Document(id=389, content: 'Niestety, ze względów bezpieczeństwa, zmiana raz nadanej nazwy użytkownika (loginu) nie jest możliwa...', score: 18.534538), Document(id=686, content: 'Aby poprawić lub zaktualizować swoje dane teleadresowe, przejdź do zakładki Dane konta Allegro. Wpro...', score: 14.254619), Document(id=394, content: 'Do sprzedaży w Allegro Ads zaliczany jest każdy zakup dokonany w ciągu 7 dni od kliknięcia użytkowni...', score: 10.396458), Document(id=855, content: 'Każdemu nowemu Klientowi serwisu, w chwili potwierdzenia adresu e-mail, automatycznie nadajemy nazwę...', score: 9.800139), Document(id=818, content: 'Tagami możesz zarządzać w zakładce Tagi. Możesz w niej:
# * utworzyć nową podkategorię,
# * zmienić nazw...', score: 9.512604), Document(id=61, content: 'Możesz zmienić imię lub nazwisko w ustawieniach konta zwykłego, jeśli:
# *     błędnie je wpiszesz pod...', score: 9.165941), Document(id=51, content: '* Konto Firma możesz przekształcić w konto zwykłe wyłącznie na swoje dane osobowe, jako właściciela ...', score: 8.130451), Document(id=17, content: 'Jeśli taki Kupujący złożył ofertę w Twojej licytacji – odwołaj ją. Podając powód odwołania oferty, z...', score: 7.7470098), Document(id=868, content: 'Jeśli chcesz, żeby Twoje oferty zdobywały coraz więcej wyświetleń i kliknięć, sugerujemy zawsze upew...', score: 7.3154745), Document(id=514, content: 'Zestawienie będzie zawierać:
# * numer i nazwę transakcji,
# * liczbę sprzedanych przedmiotów w konkretn...', score: 7.224429)]}}
# {'retriever': {'documents': [Document(id=823, content: 'Allegro Smart! kupisz w kilku prostych krokach
# 1. Do dyspozycji masz opcje z płatnością co miesiąc l...', score: 16.008686), Document(id=542, content: 'Za Allegro Smart! możesz zapłacić przelewem tradycyjnym, o ile wybierzesz opcję płatną co  12 miesię...', score: 12.573072), Document(id=201, content: 'Możesz uregulować należności za prowizje i opłaty Allegro, zgodnie z kwotą wystawionej faktury. Aby ...', score: 11.6435375), Document(id=825, content: 'O obejmujących Cię aktualnie i zakończonych promocjach dowiesz się z zakładki Moje Allegro > Moja Sp...', score: 11.476372), Document(id=629, content: 'Za Allegro Smart! zapłacisz jedynie:
# * 49 zł przy płatności za 12 miesięcy,
# * 8,99 zł przy płatności...', score: 11.303965), Document(id=794, content: 'Jeśli kupisz Allegro Smart! na stronie allegro.pl/smart, to Twoja usługa zostanie aktywowana po jej ...', score: 11.042683), Document(id=19, content: 'Utworzoną tabelę dodasz podczas wystawiania oferty w formularzu wystawiania. Możesz to zrobić równie...', score: 10.983974), Document(id=609, content: 'Jeśli wybierzesz płatność kartą, zapiszesz ją na swoim koncie. Dzięki temu ekspresowo zapłacisz za k...', score: 10.63309), Document(id=158, content: 'Zależy nam na tym, aby Kupujący mieli najlepsze doświadczenia podczas korzystania z usługi Allegro S...', score: 10.494133), Document(id=27, content: 'W takiej sytuacji spróbuj ponowić płatność. Jeśli to nie pomoże, skontaktuj się ze Sprzedającym, wów...', score: 9.88179)]}}
# {'retriever': {'documents': [Document(id=764, content: '* zaplanowany - urlop jeszcze się nie zaczął,
# * w trakcie - urlop już się rozpoczął,
# * zakończony - ...', score: 13.805323), Document(id=702, content: '* Masz 40 dni urlopu.
# * Wakacje możesz zaplanować co najmniej 7 dni przed ich rozpoczęciem.
# * Najkró...', score: 12.812064), Document(id=701, content: '1. Przejdź do zakładki Urlop.
# 2. Wybierz lub wpisz ręcznie datę rozpoczęcia i zakończenia swojego ur...', score: 12.143873), Document(id=74, content: 'Zrobisz to w zakładce Urlop. W ten sposób poinformujesz Kupujących, że wysyłka towaru może się opóźn...', score: 11.627571), Document(id=442, content: 'Informacja o nieobecności zniknie ze stron ofert w zaplanowanym przez Ciebie dniu zakończenia urlopu...', score: 11.506321), Document(id=329, content: 'Możesz zakończyć działalność w Allegro przez:
# * odstąpienie od umowy z serwisem,
# * rozwiązanie umowy...', score: 7.075403), Document(id=580, content: 'Każdy etap Dyskusji oznaczamy odpowiednimi statusami:
# * W toku - każda rozpoczęta Dyskusja między 1 ...', score: 6.704644), Document(id=207, content: 'W ramach jednej kampanii dodasz Monety do wszystkich swoich ofert.
# 1. Podaj tytuł kampanii
# 2. Okreś...', score: 6.6308265), Document(id=284, content: 'Tak, kupon zrealizujesz zarówno na zakupy zrobione na komputerze jak i w aplikacji mobilnej.', score: 5.823579), Document(id=468, content: 'W Dyskusji ze Sprzedającym:
# * powinien on odpowiedzieć Ci w ciągu 24 godzin,
# * jeśli nie uda Wam się...', score: 5.7027807)]}}
# {'retriever': {'documents': [Document(id=596, content: 'Tak, jeśli oferta została usunięta przez pracownika Allegro. Wówczas zwrócimy opłaty za wystawienie ...', score: 16.821613), Document(id=398, content: 'Nie. Jeśli koszt dostawy przedmiotu będzie wyższy niż wskazany w tabeli oraz suma kosztów dostawy pr...', score: 15.033552), Document(id=317, content: 'Statusy dla wpłat od Kupujących
# * Rozpoczęta – Kupujący rozpoczął proces płatności, nie ma jednak je...', score: 14.466425), Document(id=483, content: 'Sposoby łączenia kosztów pozwalają, by Kupującemu wyświetliła się
# * kwota najdroższej dostawy spośró...', score: 14.181635), Document(id=846, content: 'W zależności od tego jaki koszt wysyłki Sprzedający przypisze do swojej oferty lub zaproponuje darmo...', score: 13.805018), Document(id=782, content: 'Zakładka Moje konto
# Zebraliśmy w niej informacje o Twoim koncie na Allegro, czyli wpisane przez Cieb...', score: 13.426214), Document(id=184, content: 'Kupujący pokrywa koszt odesłania przedmiotu, chyba że zgodziłeś się je ponieść lub nie poinformowałe...', score: 12.891223), Document(id=508, content: 'Opłaty naliczamy co 10 dni. Jeśli Twoja oferta została wystawiona na 20 dni, opłata została doliczon...', score: 12.857153), Document(id=419, content: 'Jeśli przerwiesz wystawianie oferty i zamkniesz stronę, nie stracisz wprowadzonych danych - zapamięt...', score: 12.674745), Document(id=239, content: 'Koszty dostawy partner - Leaslink Sp z.o.o. doliczy do comiesięcznych rat leasingowych. Nie dotyczy ...', score: 12.565898)]}}
# {'retriever': {'documents': [Document(id=828, content: 'Jeśli nie chcesz już otrzymywać faktur i masz:
# Konto zwykłe
# 1. przejdź do zakładki Faktury i kliknij...', score: 18.055643), Document(id=208, content: 'Nie możemy wystawić faktur za usługi wcześniejsze, niż z miesiąca w którym aktywujesz konto fakturow...', score: 13.848922), Document(id=867, content: 'Usługa Allegro Smart! jest dostępna jedynie dla zarejestrowanych Klientów Allegro. Dowiedz się jak ł...', score: 12.776586), Document(id=79, content: 'Faktury za dany miesiąc obejmują należności naliczone w tym miesiącu. Wystawiamy je nie później, niż...', score: 11.608458), Document(id=63, content: 'Aby otworzyć konto fakturowe:
# 1. przejdź do zakładki Faktury,
# 2. wybierz formularz danych do faktury...', score: 11.569184), Document(id=733, content: 'Tak, ale warunkiem jest otwarcie konta fakturowego. Faktury mogą być wystawione tylko na dane właści...', score: 9.6338215), Document(id=51, content: '* Konto Firma możesz przekształcić w konto zwykłe wyłącznie na swoje dane osobowe, jako właściciela ...', score: 9.587507), Document(id=147, content: 'Jeżeli Twoje konto na Allegro zostało zawieszone, aby założyć nowe – musisz otrzymać naszą zgodę.
# W...', score: 8.826056), Document(id=800, content: 'Tak. Faktury wystawiamy raz w miesiącu, niezależnie od wysokości naliczonych opłat. Każdy Klient ser...', score: 8.748622), Document(id=377, content: 'Nie. Współdzielić konta nie mogą:
# * posiadacze kont Firma (po przekształceniu konta zwykłego na kont...', score: 7.8897038)]}}
# {'retriever': {'documents': [Document(id=547, content: 'Faktury wystawiane są za usługi Allegro i zawierają rozliczenie wszystkich opłat za korzystanie z us...', score: 21.086016), Document(id=662, content: 'Opłaty za opcje promowania naliczamy cyklicznie. Jeden cykl opłat to 10 dni. Gdy wystawisz ofertę, n...', score: 17.75054), Document(id=777, content: 'Oferta do wyczerpania przedmiotów nie kończy się po określonej liczbie dni, tylko trwa do wyprzedani...', score: 17.51551), Document(id=830, content: 'Kwota do zapłaty może być większa od opłat naliczonych za korzystanie z usług Allegro w danym miesią...', score: 15.567593), Document(id=508, content: 'Opłaty naliczamy co 10 dni. Jeśli Twoja oferta została wystawiona na 20 dni, opłata została doliczon...', score: 15.285011), Document(id=730, content: 'Cykliczne naliczanie opłat co 10 dni pozwala Ci łatwiej zarządzać promowaniem w trwających ofertach,...', score: 14.982073), Document(id=758, content: 'Ogłoszenie można wystawić na czas nieokreślony lub na 10, 20, 30 dni. Opłaty naliczamy co 10 dni.
# C...', score: 13.977671), Document(id=204, content: 'Nie. Opłaty naliczamy z góry i są one bezzwrotne.', score: 13.497944), Document(id=725, content: 'Gdy wznowisz ofertę, wznowimy też opłaty:
# * jeśli dany cykl opłatowy (za wystawienie, promowanie, op...', score: 13.198763), Document(id=874, content: 'Opłaty utrzymaniowej nie naliczamy w:
# * ofertach ogłoszeniowych,
# * ofertach z kategorii, w których p...', score: 12.702393)]}}
# {'retriever': {'documents': [Document(id=460, content: 'Raty Od.nowa dostępne są w ofertach promowanych przez Sprzedających wystawionych w kategoriach, w kt...', score: 24.323956), Document(id=368, content: 'Pamiętaj, że w ramach Rat Od.nowa można wielokrotnie korzystać z przyznanych przez bank środków. Każ...', score: 20.770842), Document(id=494, content: 'Wysokość środków, które możesz wykorzystać w ramach Rat Od.nowa znajdziesz w zestawieniu transakcji,...', score: 16.685097), Document(id=424, content: 'Raty Od.nowa dostępne są aktualnie w ofertach promowanych przez sprzedających w kategorii Sport i Tu...', score: 16.574705), Document(id=89, content: 'Po spłacie zakupu Twój limit na zakupy na Raty Od.nowa na Allegro będzie ponownie w całości do Twoje...', score: 15.762415), Document(id=569, content: '1. Wybierz przedmiot objęty ratami ZERO lub skompletuj koszyk, w którym co najmniej połowę wartości ...', score: 15.439827), Document(id=3, content: 'Raty Od.nowa to sposób płatności za zakupy na Allegro w ratach, w ramach odnawialnego limitu kredyto...', score: 14.384014), Document(id=343, content: 'Warunki zwrotu muszą być określone, aby Twoja oferta była oznaczona ikoną Allegro Smart! Aby to zrob...', score: 13.71197), Document(id=279, content: 'Ikoną Allegro Smart! będą oznaczone:
# 1. Oferty najlepszych Sprzedających, którzy:
#  * mają dobrą repu...', score: 12.688983), Document(id=383, content: 'Masz do wyboru dwa rodzaje zakupów na raty:
# * Raty ZERO - w ratach ZERO płacisz tylko za towar. Nie ...', score: 12.564945)]}}
# {'retriever': {'documents': [Document(id=238, content: 'Zaległości mogą dotyczyć opłat za wystawienie, prowizji od sprzedaży, abonamentów oraz opłat za kupo...', score: 13.730198), Document(id=304, content: 'Zrobisz to w zakładce Zestawienie sprzedaży. Wybierz okres za jaki chcesz otrzymać zestawienie sprze...', score: 11.804528), Document(id=514, content: 'Zestawienie będzie zawierać:
# * numer i nazwę transakcji,
# * liczbę sprzedanych przedmiotów w konkretn...', score: 11.427387), Document(id=561, content: '1. Przejdź do zakładki Zestawienia.
# 2. W części Zestawienia wskaż typ zestawienia, który chcesz przy...', score: 11.010438), Document(id=453, content: 'Zestawienie sprzedaży to liczba Twoich transakcji, przeprowadzonych w konkretnym okresie na Allegro....', score: 10.152183), Document(id=526, content: 'Sprzedaż w kategorii Ebooki prowadzić mogą wyłącznie oficjalni dystrybutorzy, po spełnieniu odpowied...', score: 9.514303), Document(id=621, content: 'W zakładce [Lista moich wypłat] możesz pobrać plik PDF z zestawieniem wpłat od Kupujących, które skł...', score: 9.0938425), Document(id=42, content: 'Menedżer Sprzedaży to aplikacja ułatwiająca zarządzanie sprzedażą na Allegro.', score: 8.785543), Document(id=513, content: 'Na stronie Twoje oceny znajdziesz zestawienie wszystkich wystawionych przez kupujących oceny sprzeda...', score: 8.354379), Document(id=596, content: 'Tak, jeśli oferta została usunięta przez pracownika Allegro. Wówczas zwrócimy opłaty za wystawienie ...', score: 8.279138)]}}
# {'retriever': {'documents': [Document(id=725, content: 'Gdy wznowisz ofertę, wznowimy też opłaty:
# * jeśli dany cykl opłatowy (za wystawienie, promowanie, op...', score: 16.932259), Document(id=574, content: 'Wyłącz promowanie przed zakończeniem bieżącego cyklu promowania. Zrobisz to przez edycję oferty. Wte...', score: 15.956762), Document(id=454, content: 'Jeśli w trwającej ofercie dodasz opcję promowania, utworzymy dla niej odrębny cykl naliczania opłat....', score: 15.757902), Document(id=309, content: 'Wyłącz promowanie przed zakończeniem bieżącego cyklu promowania. Zrobisz to poprzez edycję oferty w ...', score: 15.257763), Document(id=98, content: 'Sprawdzisz to w Historii. Cykl trwa 10 dni od momentu, gdy naliczyliśmy opłaty.
# Możesz również spraw...', score: 13.339615), Document(id=662, content: 'Opłaty za opcje promowania naliczamy cyklicznie. Jeden cykl opłat to 10 dni. Gdy wystawisz ofertę, n...', score: 12.345041), Document(id=788, content: 'Kiedy reklamujesz się w Allegro Ads samodzielnie decydujesz, jaki budżet chcesz przeznaczyć na rekla...', score: 11.951118), Document(id=436, content: 'Jeśli w trwającej ofercie dodasz opcję promowania, utworzymy dla niej odrębny cykl naliczania opłat,...', score: 11.822865), Document(id=354, content: 'Nie. W trakcie jednego cyklu możesz w dowolnym momencie wyłączyć promowanie. Nie wpłynie to jednak n...', score: 10.565237), Document(id=221, content: 'Koszt promowania ofert sponsorowanych możesz sprawdzić w panelu Allegro Ads w zakładce Statystyki lu...', score: 10.560959)]}}
# {'retriever': {'documents': [Document(id=271, content: 'Twoja ocena za czas wysyłki będzie miała automatycznie 5 gwiazdek, jeśli:
# * udostępniłeś Klientowi n...', score: 17.744055), Document(id=92, content: 'Znajdź właściwe zamówienie w zakładce i kliknij [Numer przesyłki].
# Następnie wybierz z listy przewoź...', score: 12.622556), Document(id=636, content: 'Każdy etap płatności w Allegro Finanse jest oznaczony odpowiednim statusem. Możesz je sprawdzać na b...', score: 12.194898), Document(id=261, content: '1. Przejdź na kartę wybranej transakcji - kliknij [numer transakcji] w zakładce Transakcje,
# 2. w czę...', score: 11.668351), Document(id=132, content: '1. Przejdź do zakładki Zamówienia i przy wybranej transakcji ze statusem płatności "Zakończona" oraz...', score: 10.746007), Document(id=541, content: 'Status przesyłki sprawdzisz
# * w szczegółach wybranego zamówienia w zakładce Kupione,
# * w zakładce Li...', score: 10.568526), Document(id=565, content: 'Wejdź do panelu reklamowego i sprawdź status swojej kampanii w widoku konta. Kampania może mieć nast...', score: 10.24625), Document(id=49, content: 'Każda płatność na początku ma status Rozpoczęta
# Jeśli ten status się nie zmienia sprawdź, czy środki...', score: 10.027425), Document(id=891, content: '* Możliwość śledzenia przesyłki ma znaczenie dla 89% kupujących, z kolei aż 72% kupujących korzysta ...', score: 9.740295), Document(id=275, content: 'Zapłatę za przedmiot przesłany do Ciebie przesyłką pobraniową potwierdzasz z chwilą odbioru takiej p...', score: 9.299818)]}}
# {'retriever': {'documents': [Document(id=730, content: 'Cykliczne naliczanie opłat co 10 dni pozwala Ci łatwiej zarządzać promowaniem w trwających ofertach,...', score: 16.566694), Document(id=777, content: 'Oferta do wyczerpania przedmiotów nie kończy się po określonej liczbie dni, tylko trwa do wyprzedani...', score: 15.453968), Document(id=547, content: 'Faktury wystawiane są za usługi Allegro i zawierają rozliczenie wszystkich opłat za korzystanie z us...', score: 15.35556), Document(id=662, content: 'Opłaty za opcje promowania naliczamy cyklicznie. Jeden cykl opłat to 10 dni. Gdy wystawisz ofertę, n...', score: 14.042795), Document(id=830, content: 'Kwota do zapłaty może być większa od opłat naliczonych za korzystanie z usług Allegro w danym miesią...', score: 13.175773), Document(id=508, content: 'Opłaty naliczamy co 10 dni. Jeśli Twoja oferta została wystawiona na 20 dni, opłata została doliczon...', score: 11.110092), Document(id=120, content: 'Bieżące saldo Twojego konta sprawdzisz w zakładce Bieżące saldo i wpłata.
# Jeśli Twoje saldo będzie u...', score: 11.069595), Document(id=758, content: 'Ogłoszenie można wystawić na czas nieokreślony lub na 10, 20, 30 dni. Opłaty naliczamy co 10 dni.
# C...', score: 10.126268), Document(id=725, content: 'Gdy wznowisz ofertę, wznowimy też opłaty:
# * jeśli dany cykl opłatowy (za wystawienie, promowanie, op...', score: 9.9983635), Document(id=454, content: 'Jeśli w trwającej ofercie dodasz opcję promowania, utworzymy dla niej odrębny cykl naliczania opłat....', score: 9.820231)]}}
# {'retriever': {'documents': [Document(id=879, content: 'W niektórych kategoriach na Allegro nie zapłacisz przez Allegro Finanse, ponieważ prezentowane w nic...', score: 15.332543), Document(id=885, content: 'Nie, należy zapłacić za zakupy z góry, wybierając płatność przez Allegro Finanse.', score: 12.775222), Document(id=119, content: 'Nie, kuponem należy zapłacić za zakupy z góry, przy płatności przez Allegro Finanse.', score: 12.621745), Document(id=457, content: 'Wystarczy, że po rejestracji konta zalogujesz się na Allegro i coś kupisz. Jeśli podczas zapłaty za ...', score: 12.430957), Document(id=23, content: 'Za każdym razem, kiedy potwierdzisz chęć zakupu przyciskiem [kupuję i płacę], możesz mieć pewność, ż...', score: 11.725443), Document(id=593, content: 'Podczas zakupów bez rejestracji pamiętaj o kilku podstawowych zasadach:
# * możesz zrobić zakupy w mak...', score: 10.932406), Document(id=710, content: 'Narzędzia, do których masz dostęp z zawieszonym kontem
# *     Moje Allegro – zarządzanie zakończonymi...', score: 10.842865), Document(id=123, content: 'Pod nazwą Allegro Finanse prezentujemy usługi PayU i Przelewy24, dzięki którym kupujący mogą łatwo i...', score: 10.75519), Document(id=161, content: 'Do koszyka nie możesz dodać:
# * licytacji (w koszyku mogą znaleźć się jedynie oferty kup teraz),
# * of...', score: 10.72171), Document(id=460, content: 'Raty Od.nowa dostępne są w ofertach promowanych przez Sprzedających wystawionych w kategoriach, w kt...', score: 10.015393)]}}
# {'retriever': {'documents': [Document(id=846, content: 'W zależności od tego jaki koszt wysyłki Sprzedający przypisze do swojej oferty lub zaproponuje darmo...', score: 15.308269), Document(id=455, content: 'Leasing na Allegro dostępny jest zarówno dla kont zwykłych, jak i firmowych. Stroną umowy finansowan...', score: 12.262837), Document(id=244, content: 'Za zakupy na Allegro zapłacisz w kilku prostych krokach
# 1. Kup przedmiot przez [kup teraz] lub przez...', score: 10.335122), Document(id=142, content: 'Ocena sprzedaży to opinia, jaką o transakcji wystawia Kupujący. Do oceny sprzedaży może dodać koment...', score: 10.036615), Document(id=376, content: 'W formularzu wystawiania, przy co najmniej jednej z wymienionych opcji dostawy, wpisz 0 zł jako kosz...', score: 9.968934), Document(id=856, content: 'Jeśli posiadasz kilka kont w serwisie, fakturę do każdego z nich opłać osobno, nawet jeżeli są one w...', score: 9.460361), Document(id=873, content: 'Jeśli Twój Klient wybierze ofertę z dostawą realizowaną w ramach usługi Allegro Smart!, koszt tej do...', score: 9.232069), Document(id=799, content: 'Allegro Ads są rozliczane w modelu, w którym płacisz nie za wyświetlenie, a jedynie za kliknięcie re...', score: 8.95309), Document(id=358, content: 'Zadowolenie kupujących wyliczamy na podstawie średniej liczby gwiazdek, jakie w ciągu 30 dni Kupując...', score: 8.869303), Document(id=507, content: 'Gdy Kupujący wybierze opcję "weź w leasing”, przejdzie do wniosku na stronie naszego partnera (leasi...', score: 8.835332)]}}
# {'retriever': {'documents': [Document(id=872, content: 'Oznaczenia o dostępnej wysyłce w ramach Allegro Smart! wprowadzimy na liście ofert, na stronach samy...', score: 18.48729), Document(id=616, content: 'Nie, bezpłatna dostawa w ramach Allegro Smart! jest dostępna jedynie dla zamówień opłaconych z góry....', score: 18.060648), Document(id=564, content: 'Z Allegro Smart! skorzystasz, jeśli:
# * Cena jednego przedmiotu lub łączna cena wielu przedmiotów od ...', score: 17.217628), Document(id=55, content: 'Z Allegro Smart! skorzystasz, jeśli:
# * Cena jednego przedmiotu lub łączna cena wielu przedmiotów od ...', score: 16.830307), Document(id=430, content: 'Nie. Okres ochrony w ramach ubezpieczenia jest określony z góry. Informacje na ten temat znajdziesz ...', score: 14.120012), Document(id=387, content: 'Aby skorzystać z pomocy w ramach Alleopona zadzwoń pod numer: 801 402 204 (dostępny 24 godziny na do...', score: 13.720378), Document(id=792, content: 'Z bezpłatnej dostawy w ramach Allegro Smart! skorzystasz tylko 1 raz w ramach tej samej transakcji. ...', score: 13.619676), Document(id=48, content: 'Bezpłatne zwroty w ramach Allegro Smart! są dostępne dla wszystkich punktów odbioru i Paczkomatów. Z...', score: 13.468972), Document(id=867, content: 'Usługa Allegro Smart! jest dostępna jedynie dla zarejestrowanych Klientów Allegro. Dowiedz się jak ł...', score: 13.225725), Document(id=339, content: '1. W zakładce Kupione znajdź przedmiot, który chcesz zwrócić i kliknij szczegóły. Wybierz opcję zwró...', score: 13.19334)]}}
# {'retriever': {'documents': [Document(id=266, content: 'Ze względu na wątpliwości natury etycznej i prawnej, na Allegro nie można sprzedawać prac magistersk...', score: 29.815023), Document(id=364, content: 'Na Allegro nie można sprzedawać kart gwarancyjnych jako samodzielnych przedmiotów. Możesz je sprzeda...', score: 11.619672), Document(id=115, content: 'Na Allegro nie można sprzedawać:
# * złota w postaci sztabek,
# * monet bądź złomu złotniczego,
# * srebr...', score: 10.610284), Document(id=581, content: 'Na Allegro nie można sprzedawać dowodów rejestracyjnych oraz kart pojazdu oferowanych bez pojazdów, ...', score: 9.638234), Document(id=402, content: 'Na Allegro można sprzedawać wyroby tytoniowe pod warunkiem, że mają one charakter kolekcjonerski.
# Za...', score: 9.445928), Document(id=920, content: 'Nie, nie można umieszczać na miniaturach wszelkich dodatkowych obiektów graficznych, napisów, piktog...', score: 9.294338), Document(id=265, content: 'Na Allegro nie można sprzedawać kuponów zniżkowych (rabatowych), uprawniających do uzyskania upustu ...', score: 9.113218), Document(id=112, content: 'Na Allegro nie można sprzedawać materiałów wybuchowych. Niedozwolona jest sprzedaż między innymi pro...', score: 8.95659), Document(id=735, content: 'Na Allegro nie można sprzedawać organów ludzkich i zwierzęcych. Niedozwolona jest sprzedaż m.in. zwł...', score: 8.866821), Document(id=182, content: 'Na Allegro nie można sprzedawać zarejestrowanych telefonicznych kart prepaid. Ograniczenie to wynika...', score: 8.667689)]}}
# {'retriever': {'documents': [Document(id=905, content: 'Prawo polskie nie zezwala na odsprzedaż biletów tego typu z zyskiem oraz na nabywanie ich w celu ods...', score: 24.788013), Document(id=265, content: 'Na Allegro nie można sprzedawać kuponów zniżkowych (rabatowych), uprawniających do uzyskania upustu ...', score: 12.878063), Document(id=112, content: 'Na Allegro nie można sprzedawać materiałów wybuchowych. Niedozwolona jest sprzedaż między innymi pro...', score: 12.380939), Document(id=364, content: 'Na Allegro nie można sprzedawać kart gwarancyjnych jako samodzielnych przedmiotów. Możesz je sprzeda...', score: 12.3753395), Document(id=115, content: 'Na Allegro nie można sprzedawać:
# * złota w postaci sztabek,
# * monet bądź złomu złotniczego,
# * srebr...', score: 12.299132), Document(id=182, content: 'Na Allegro nie można sprzedawać zarejestrowanych telefonicznych kart prepaid. Ograniczenie to wynika...', score: 11.843861), Document(id=632, content: 'W związku z regulacjami prawnymi, na Allegro nie można sprzedawać rybackich narzędzi oraz urządzeń p...', score: 11.212286), Document(id=914, content: 'Wynika to z obowiązujących przepisów. Zgodnie z nimi indywidualni nabywcy złota (w postaci sztabek, ...', score: 11.187733), Document(id=735, content: 'Na Allegro nie można sprzedawać organów ludzkich i zwierzęcych. Niedozwolona jest sprzedaż m.in. zwł...', score: 11.02893), Document(id=402, content: 'Na Allegro można sprzedawać wyroby tytoniowe pod warunkiem, że mają one charakter kolekcjonerski.
# Za...', score: 10.949444)]}}
# {'retriever': {'documents': [Document(id=704, content: 'Jeśli sprzedasz przedmiot, ale transakcja nie dojdzie do skutku, możesz ubiegać się o przyznanie zwr...', score: 28.602491), Document(id=84, content: 'Jeśli pozytywnie zakończyłeś transakcję z Kupującym już po tym, jak wystąpiłeś o zwrot prowizji (rab...', score: 22.550823), Document(id=367, content: 'Rabat transakcyjny (zwrot prowizji) rozliczany jest w miesiącu, w którym został przyznany (nie ma zn...', score: 21.840803), Document(id=146, content: 'Jeśli Kupujący
# * nie opłacił zamówienia,
# * nie odpowiada na próby kontaktu,
# * zrezygnował z zakupu,
# ...', score: 20.786026), Document(id=554, content: 'Z leasingu w Allegro możesz skorzystać dzięki naszej współpracy z firmą LeaseLink Sp. z o. o., która...', score: 13.165011), Document(id=612, content: 'Jeśli ubiegasz się o zwrot prowizji (rabat transakcyjny), ponieważ nie masz kontaktu z Kupującym, pr...', score: 12.748987), Document(id=196, content: 'O zwrot prowizji możesz wystąpić przez 45 dni od chwili zawarcia transakcji.', score: 12.108617), Document(id=299, content: 'To proste. W tej zakładce sprawdzisz, ile pieniędzy możesz otrzymać. Następnie wystarczy, że wypełni...', score: 11.752591), Document(id=915, content: '1. Zaplanuj wystawianie przedmiotów tak, aby ostatnie z Twoich ofert kończyły się kilka dni przed za...', score: 11.381798), Document(id=295, content: '1. Wypełnij formularz on-line
# W terminie 14 - 180 dni (czyli do 6 miesięcy) od dnia zakupu wypełnij ...', score: 11.338373)]}}
# {'retriever': {'documents': [Document(id=722, content: 'Aby pobrać dane osobowe, które zgromadziliśmy podczas Twojego korzystania z Allegro:
# 1. Wejdź na str...', score: 12.176381), Document(id=741, content: 'Tak, możesz posiadać kilka kont, o ile zarejestrujesz je na swoje poprawne i prawdziwe dane osobowe....', score: 11.539678), Document(id=485, content: 'Każdy Klient Allegro może podać w ustawieniach konta dodatkowe adresy do wysyłki.
# W Formularzu opcj...', score: 9.943194), Document(id=327, content: 'Nie ma takiej możliwości. Środki zgromadzone na saldzie Allegro Finanse możesz wypłacić wyłącznie na...', score: 8.804601), Document(id=487, content: 'Aby usunąć swoje dane osobowe z Allegro, najpierw rozwiąż umowę z serwisem. Usuniemy je, jeśli nie b...', score: 8.800408), Document(id=727, content: 'Zgromadzone środki wyświetlimy w ramach dwóch odrębnych sald w zakładce Saldo i wypłata środków, ale...', score: 8.506868), Document(id=479, content: 'Aby uruchomić usługę Przelewy24, musisz mieć aktywowaną usługę PayU. Następnie:
# 1. Jeśli Twoja weryf...', score: 8.358194), Document(id=782, content: 'Zakładka Moje konto
# Zebraliśmy w niej informacje o Twoim koncie na Allegro, czyli wpisane przez Cieb...', score: 8.178163), Document(id=51, content: '* Konto Firma możesz przekształcić w konto zwykłe wyłącznie na swoje dane osobowe, jako właściciela ...', score: 7.8026648), Document(id=861, content: 'Tak. Zakupy u różnych sprzedających zapiszemy wtedy jako osobne pozycje w menu Planowane zakupy, ale...', score: 7.620104)]}}
# {'retriever': {'documents': [Document(id=142, content: 'Ocena sprzedaży to opinia, jaką o transakcji wystawia Kupujący. Do oceny sprzedaży może dodać koment...', score: 9.9260025), Document(id=782, content: 'Zakładka Moje konto
# Zebraliśmy w niej informacje o Twoim koncie na Allegro, czyli wpisane przez Cieb...', score: 9.621579), Document(id=224, content: 'Zakładka Moja sprzedaż
# *     Licytacje i Kup Teraz - ta sekcja zawiera informacje na temat Twojej sp...', score: 8.614512), Document(id=194, content: 'Cena minimalna, która występuje w niektórych licytacjach, to najniższa kwota, za jaką Sprzedający zg...', score: 8.298955), Document(id=9, content: 'Aby przystąpić o Strefy okazji musisz posiadać
# * konto firmowe
# * ocena sprzedaży powyżej 98% za osta...', score: 8.025831), Document(id=513, content: 'Na stronie Twoje oceny znajdziesz zestawienie wszystkich wystawionych przez kupujących oceny sprzeda...', score: 7.7626505), Document(id=407, content: 'Opinie produktowe to oceny konkretnego przedmiotu, które zamieszczają jego posiadacze. Dotyczą wyłąc...', score: 7.5837812), Document(id=90, content: 'Gdy sortujemy oferty w ten sposób, bierzemy pod uwagę wiele czynników. Możemy je podzielić na:
# Dane ...', score: 7.224768), Document(id=905, content: 'Prawo polskie nie zezwala na odsprzedaż biletów tego typu z zyskiem oraz na nabywanie ich w celu ods...', score: 6.8865466), Document(id=229, content: 'Aby móc promować swoje oferty za pomocą Monet:
#  * Musisz posiadać konto firmowe,
#  * Twoja średnia oc...', score: 6.825381)]}}
# {'retriever': {'documents': [Document(id=795, content: 'Przykład:
# Kupujesz na Raty Od.nowa przedmiot, którego wartość wraz z kosztem wysyłki wynosi 1450 zł....', score: 36.572628), Document(id=3, content: 'Raty Od.nowa to sposób płatności za zakupy na Allegro w ratach, w ramach odnawialnego limitu kredyto...', score: 34.88625), Document(id=268, content: 'Jeśli urządzasz mieszkanie, myślisz o nowym komputerze lub po prostu w najbliższym czasie możliwe, ż...', score: 23.890308), Document(id=368, content: 'Pamiętaj, że w ramach Rat Od.nowa można wielokrotnie korzystać z przyznanych przez bank środków. Każ...', score: 22.031826), Document(id=5, content: 'We współpracy z mBankiem przygotowaliśmy kredyt przeznaczony dla firm sprzedających na Allegro. Ofer...', score: 15.096446), Document(id=89, content: 'Po spłacie zakupu Twój limit na zakupy na Raty Od.nowa na Allegro będzie ponownie w całości do Twoje...', score: 14.832793), Document(id=194, content: 'Cena minimalna, która występuje w niektórych licytacjach, to najniższa kwota, za jaką Sprzedający zg...', score: 12.865164), Document(id=557, content: 'Wysokość limitu kredytowego wyliczamy na podstawie Twoich obrotów na Allegro w ciągu ostatnich 12 mi...', score: 12.431298), Document(id=298, content: 'Uzyskany kredyt zasili saldo na Twoim rachunku, otwartym razem z kredytem. Oznacza to, że z dodatkow...', score: 11.256548), Document(id=383, content: 'Masz do wyboru dwa rodzaje zakupów na raty:
# * Raty ZERO - w ratach ZERO płacisz tylko za towar. Nie ...', score: 10.617457)]}}
# {'retriever': {'documents': [Document(id=438, content: 'Kiedy kupujący wypełni formularz odstąpienia od umowy na jego koncie Allegro, wyślemy do Ciebie powi...', score: 14.017936), Document(id=167, content: 'I. Sprawdź, czy możesz zwrócić przedmiot. Towar kupiony z dostawą Allegro Smart! możesz zwrócić za d...', score: 11.069603), Document(id=342, content: 'Przy zakupie usługi Allegro Smart! nie możesz wykorzystać Monet.', score: 10.723617), Document(id=834, content: 'Sprawdź na Twoim koncie Allegro, w zakładce Allegro Smart! czy usługa została wyłączona.
# Jeśli usług...', score: 10.317608), Document(id=794, content: 'Jeśli kupisz Allegro Smart! na stronie allegro.pl/smart, to Twoja usługa zostanie aktywowana po jej ...', score: 10.208767), Document(id=899, content: 'Jeśli strony panelu Allegro Ads nie wyświetlają się na Twoim urządzeniu prawidłowo, sprawdź, czy pro...', score: 10.198002), Document(id=917, content: 'Bez pełnej aktywacji konta, Klienci serwisu mają ograniczony dostęp do niektórych usług - na przykła...', score: 9.769515), Document(id=823, content: 'Allegro Smart! kupisz w kilku prostych krokach
# 1. Do dyspozycji masz opcje z płatnością co miesiąc l...', score: 9.738858), Document(id=758, content: 'Ogłoszenie można wystawić na czas nieokreślony lub na 10, 20, 30 dni. Opłaty naliczamy co 10 dni.
# C...', score: 9.626556), Document(id=77, content: 'Przedmioty zabytkowe i dobra kultury możesz kupować jedynie od osób, które są ich legalnymi właścici...', score: 9.1939945)]}}
# ...
# 3. wybierz oferty i okre...', score: 9.986816), Document(id=207, content: 'W ramach jednej kampanii dodasz Monety do wszystkich swoich ofert.
# 1. Podaj tytuł kampanii
# 2. Okreś...', score: 9.6099415), Document(id=268, content: 'Jeśli urządzasz mieszkanie, myślisz o nowym komputerze lub po prostu w najbliższym czasie możliwe, ż...', score: 9.251859), Document(id=914, content: 'Wynika to z obowiązujących przepisów. Zgodnie z nimi indywidualni nabywcy złota (w postaci sztabek, ...', score: 8.634856)]}}
# {'retriever': {'documents': [Document(id=784, content: 'To świetnie rozpoznawalne wśród kupujących oznaczenie ofert w Strefie okazji. Oznacznenie OKAZJA jes...', score: 21.931778), Document(id=763, content: 'Ten sposób oznaczania ofert dedykujemy tylko stałym i aktywnym Partnerom Strefy okazji. Do końca 201...', score: 16.756893), Document(id=610, content: 'Opłatę pobieramy za oznaczenia, które pokazujemy na listach ofert. Opłata uzależniona jest od typu o...', score: 13.649092), Document(id=707, content: 'Strefa okazji to dział atrakcyjnych ofert wybranych przez naszych specjalistów, wystawianych przez s...', score: 12.428772), Document(id=761, content: 'Smart! okazje to specjalnie wyselekcjonowane oferty od najlepszych Sprzedających, dostępne wyłącznie...', score: 12.049678), Document(id=839, content: '* przejdź do zakładki Moje oferty
# * wybierz ofertę, którą chcesz oznaczyć
# * przy ofercie kliknij [Zg...', score: 11.715361), Document(id=179, content: 'To oznaczenie dla ofert w czasowo obniżonych cenach. Oznaczenia w czerwonym kolorze i z przekreśloną...', score: 11.656599), Document(id=9, content: 'Aby przystąpić o Strefy okazji musisz posiadać
# * konto firmowe
# * ocena sprzedaży powyżej 98% za osta...', score: 11.177005), Document(id=183, content: 'Zakończone oferty ponownie wystawisz w zakładce Moje oferty.
# Jak to zrobić
# 1. Przy wybranej ofercie ...', score: 10.615463), Document(id=86, content: 'Strefa okazji to
# * różnorodność modeli, kolorów i rozmiarów,
# * dodatkowe gratisy,
# * szeroki wybór fo...', score: 10.473209)]}}
# {'retriever': {'documents': [Document(id=556, content: 'W sytuacji, gdy Sprzedający nie udzielił odpowiedzi w wymaganym czasie (24 godziny), pracownik Alleg...', score: 21.447252), Document(id=468, content: 'W Dyskusji ze Sprzedającym:
# * powinien on odpowiedzieć Ci w ciągu 24 godzin,
# * jeśli nie uda Wam się...', score: 19.13947), Document(id=806, content: 'Dyskusje są jednym ze sposobów kontaktu między Kupującym i Sprzedającym. Gdy Kupujący zgłasza nam pr...', score: 17.553759), Document(id=108, content: '* 48 godzin od zakupu - po tym czasie Kupujący może rozpocząć dyskusję.
# * 24 godziny - tyle czasu ma...', score: 15.882046), Document(id=566, content: 'Sprzedający powinien zwrócić Ci środki w ciągu 14 dni od otrzymania Twojego oświadczenia o odstąpien...', score: 14.693915), Document(id=280, content: 'Jeśli Kupujący rozpoczął z Tobą Dyskusję
# * masz obowiązek udzielenia odpowiedzi Kupującemu w ciągu 2...', score: 11.887753), Document(id=7, content: 'Nierozwiązane dyskusje liczymy w następujący sposób - udział procentowy zaokrąglamy do drugiego miej...', score: 11.56217), Document(id=452, content: '* Jeśli Kupujący zakłada Dyskusję, odpowiedz mu jak najszybciej. Nasi najlepsi sprzedający pierwsze ...', score: 9.821195), Document(id=63, content: 'Aby otworzyć konto fakturowe:
# 1. przejdź do zakładki Faktury,
# 2. wybierz formularz danych do faktury...', score: 9.398962), Document(id=580, content: 'Każdy etap Dyskusji oznaczamy odpowiednimi statusami:
# * W toku - każda rozpoczęta Dyskusja między 1 ...', score: 9.39747)]}}
# {'retriever': {'documents': [Document(id=762, content: '* Reklama graficzna na Allegro, w odróżnieniu do wyróżnień i promowania ofert, które dotyczą konkret...', score: 18.413963), Document(id=842, content: 'Skorzystanie z reklamy graficznej wymaga złożenia zlecenia zakupu w Biurze Reklamy Allegro. W zlecen...', score: 17.599094), Document(id=555, content: 'Reklama graficzna to jedna z możliwości promowania Twoich ofert na Allegro. Polega ona na wyświetlan...', score: 13.684758), Document(id=899, content: 'Jeśli strony panelu Allegro Ads nie wyświetlają się na Twoim urządzeniu prawidłowo, sprawdź, czy pro...', score: 11.79047), Document(id=788, content: 'Kiedy reklamujesz się w Allegro Ads samodzielnie decydujesz, jaki budżet chcesz przeznaczyć na rekla...', score: 10.837898), Document(id=394, content: 'Do sprzedaży w Allegro Ads zaliczany jest każdy zakup dokonany w ciągu 7 dni od kliknięcia użytkowni...', score: 7.9404225), Document(id=799, content: 'Allegro Ads są rozliczane w modelu, w którym płacisz nie za wyświetlenie, a jedynie za kliknięcie re...', score: 7.0807214), Document(id=490, content: 'W zakładce Statystyki możesz sprawdzać wyniki swojej kampanii, grupy reklam oraz poszczególnych ofer...', score: 6.557383), Document(id=283, content: 'Dla Ciebie oznacza to bardziej efektywne wykorzystanie budżetu. Zazwyczaj wahania nie są duże - maks...', score: 6.5547156), Document(id=729, content: 'Allegro Ads to reklama Twoich ofert na Allegro. Do dyspozycji masz panel reklamowy w którym samodzie...', score: 6.3384395)]}}
# {'retriever': {'documents': [Document(id=193, content: 'Postaraj się, aby jakość Twoich ocen na koncie, które bierze udział w promocji nie spadła poniżej 98...', score: 51.23151), Document(id=100, content: 'Dokładny termin otrzymania kuponu jest zdefiniowany w regulaminie promocji, w której bierzesz udział...', score: 30.159369), Document(id=600, content: 'Monety możesz zdobywać na 2 sposoby:
# * kupuj w ofertach oznaczonych ikoną:
# * bierz udział w naszych ...', score: 27.740309), Document(id=72, content: 'Tak, możesz zrezygnować z udziału w promocji najpóźniej 7 dni przed zakończeniem cyklu rozliczeniowe...', score: 27.406672), Document(id=763, content: 'Ten sposób oznaczania ofert dedykujemy tylko stałym i aktywnym Partnerom Strefy okazji. Do końca 201...', score: 21.318882), Document(id=208, content: 'Nie możemy wystawić faktur za usługi wcześniejsze, niż z miesiąca w którym aktywujesz konto fakturow...', score: 19.451628), Document(id=409, content: 'Jeśli masz konto firmowe i spełniasz poniższe warunki, możesz zostać Super Sprzedawcą:
# *  Zrealizowa...', score: 18.867193), Document(id=784, content: 'To świetnie rozpoznawalne wśród kupujących oznaczenie ofert w Strefie okazji. Oznacznenie OKAZJA jes...', score: 17.88133), Document(id=683, content: 'Ponieważ promujemy dobre zdjęcia, które są zgodne z naszymi wymaganiami.
# Jeśli zmieniłeś pierwsze z...', score: 17.856504), Document(id=141, content: 'Informacje o Twoim koncie znajdziesz na stronie Moje Allegro.
# Zgrupowaliśmy je w trzech głównych zak...', score: 17.660072)]}}
# {'retriever': {'documents': [Document(id=46, content: '1. Dane do faktur zmienisz w zakładce Dane konta Allegro. Zmiana danych w ustawieniach konta Allegro...', score: 19.567276), Document(id=835, content: 'Tak, możesz otrzymać fakturę. Faktury VAT wystawiamy w cyklu miesięcznym, ostatniego dnia okresu roz...', score: 18.934345), Document(id=208, content: 'Nie możemy wystawić faktur za usługi wcześniejsze, niż z miesiąca w którym aktywujesz konto fakturow...', score: 17.56175), Document(id=550, content: '1. W zakładce Dane konta Allegro wpisz nazwę swojej firmy i numer NIP oraz załącz skany dokumentów r...', score: 16.487587), Document(id=866, content: '1. Swoje dane zmienisz w zakładce Faktury.
# 2. Jeżeli chcesz otrzymywać faktury na inny adres, niż te...', score: 16.003086), Document(id=79, content: 'Faktury za dany miesiąc obejmują należności naliczone w tym miesiącu. Wystawiamy je nie później, niż...', score: 14.573997), Document(id=857, content: 'W przypadku firm zarejestrowanych poza granicami Polski, w jednym z państw Unii Europejskiej, dane d...', score: 14.3593235), Document(id=906, content: 'W menu Planowane zakupy zmienisz liczbę dni, co jaką realizujemy automatyczne zakupy, pominiesz kole...', score: 14.164683), Document(id=63, content: 'Aby otworzyć konto fakturowe:
# 1. przejdź do zakładki Faktury,
# 2. wybierz formularz danych do faktury...', score: 14.095964), Document(id=538, content: 'Wystawiamy faktury wyłącznie nabywcom usług serwisu, czyli podmiotom, które zarejestrowały konto w s...', score: 13.77756)]}}
# {'retriever': {'documents': [Document(id=110, content: 'Za pośrednictwem Allegro Finanse możesz zapłacić tylko za wszystkie Misie razem.
# Jeśli chcesz zapłac...', score: 26.848278), Document(id=23, content: 'Za każdym razem, kiedy potwierdzisz chęć zakupu przyciskiem [kupuję i płacę], możesz mieć pewność, ż...', score: 20.946205), Document(id=119, content: 'Nie, kuponem należy zapłacić za zakupy z góry, przy płatności przez Allegro Finanse.', score: 16.328405), Document(id=841, content: 'Tak, zwrócimy Ci prowizję w formie rabatu transakcyjnego jeśli nie doszło do zrealizowania umowy z o...', score: 15.900731), Document(id=669, content: 'Misie są bardzo popularne, dlatego może zdarzyć się sytuacja, że chwilowo będą niedostępne.
# Zachęca...', score: 14.628561), Document(id=288, content: 'Sprzedaż Misiów prowadzona jest wyłącznie na koncie Allegro_CSR.
# Wybranego Misia możesz kupić także ...', score: 14.539389), Document(id=542, content: 'Za Allegro Smart! możesz zapłacić przelewem tradycyjnym, o ile wybierzesz opcję płatną co  12 miesię...', score: 13.874869), Document(id=277, content: '* Kupując poszczególne przedmioty, w momencie płatności wybierz opcję później. Aby zapłacić za wszys...', score: 13.319963), Document(id=875, content: 'Prowizji od sprzedaży nie naliczamy w kategoriach ogłoszeniowych (Samochody, Motocykle i quady; Używ...', score: 13.29454), Document(id=401, content: 'Tak, rachunki za usługi Allegro możesz opłacić kartą.
# Aby to zrobić
# 1. Przejdź do zakładki Bieżące s...', score: 12.946741)]}}
# {'retriever': {'documents': [Document(id=840, content: 'Nie, klient takiej informacji nie otrzyma. Informację o płatności prześle Ci operator płatności - Do...', score: 25.711617), Document(id=438, content: 'Kiedy kupujący wypełni formularz odstąpienia od umowy na jego koncie Allegro, wyślemy do Ciebie powi...', score: 18.981407), Document(id=770, content: 'Gdy Kupujący wypełni formularz, otrzymasz go w formie wiadomości e-mail. Dane na temat zakupów od Tw...', score: 15.390647), Document(id=45, content: 'Zasady otrzymywania kuponów określa Regulamin danej akcji, który znajdziesz na stronie kupony.allegr...', score: 13.693287), Document(id=720, content: 'Na Twój e-mail z ustawień konta Allegro otrzymasz powiadomienie z informacją o wysokości potrzebnej ...', score: 13.292285), Document(id=852, content: 'Statusy wpłat sprawdzisz
# * w zakładce Lista wpłat od Kupujących - kliknij na numer płatności,
# * w za...', score: 11.720319), Document(id=316, content: 'Odnotowanie wpłaty na saldzie Allegro Finanse jest równoznaczne z jej otrzymaniem. Z tą chwilą po Tw...', score: 11.444429), Document(id=435, content: 'Dodatkowe informacje o dostawie i płatności umieścisz podczas wystawiania przedmiotu, w części Dosta...', score: 11.108127), Document(id=459, content: 'Jeśli w danej kategorii nie będzie przedmiotów, które Cię interesują, wyszukiwarka sprawdzi również ...', score: 11.070629), Document(id=99, content: 'Płatność za kuriera regulujesz u operatora płatności współpracującego z Furgonetka.pl, czyli u DotPa...', score: 10.9543085)]}}
# {'retriever': {'documents': [Document(id=157, content: 'Zabezpieczamy zdjęcia cyfrowo, zapisując unikalne dane, które pozwalają na identyfikację właściciela...', score: 13.295415), Document(id=462, content: 'Zrobisz to w konkretnym zamówieniu, w zakładce Kupione. Do jednej transakcji możesz rozpocząć tylko ...', score: 11.446334), Document(id=474, content: 'Tak. Możesz zamówić kuriera kilka razy do tego samego zamówienia. Rozwiązuje to problem, gdy zamówie...', score: 10.6251955), Document(id=803, content: 'Dzięki nowej zakładce Zamówienia zarządzanie Twoją sprzedażą będzie łatwiejsze. Prezentujemy w niej ...', score: 10.419636), Document(id=149, content: 'Celem miniaturek jest jak najlepsze zaprezentowanie sprzedawanego przedmiotu Klientowi. Zdjęcia prod...', score: 8.878305), Document(id=110, content: 'Za pośrednictwem Allegro Finanse możesz zapłacić tylko za wszystkie Misie razem.
# Jeśli chcesz zapłac...', score: 7.8491664), Document(id=485, content: 'Każdy Klient Allegro może podać w ustawieniach konta dodatkowe adresy do wysyłki.
# W Formularzu opcj...', score: 7.7352257), Document(id=171, content: 'W zakładce Zamówienia masz do wyboru poniższe filtry:
# 1. Do wysłania - dostępne są zamówienia ze sta...', score: 7.591524), Document(id=523, content: 'Kiedy Kupujący po zakupie wypełni formularz opcji dostawy i płatności, poinformujemy Cię o tym w e-m...', score: 7.3269253), Document(id=535, content: 'Jeśli nie dotarł do Ciebie e-mail z danymi Kupującego, nic straconego. Po zakończeniu transakcji, in...', score: 7.2461476)]}}
# {'retriever': {'documents': [Document(id=147, content: 'Jeżeli Twoje konto na Allegro zostało zawieszone, aby założyć nowe – musisz otrzymać naszą zgodę.
# W...', score: 25.613934), Document(id=917, content: 'Bez pełnej aktywacji konta, Klienci serwisu mają ograniczony dostęp do niektórych usług - na przykła...', score: 20.309925), Document(id=308, content: 'Jeśli do końca miesiąca rozliczeniowego nie otrzymamy pełnej kwoty do zapłaty z faktury, na Twoje ko...', score: 19.790878), Document(id=377, content: 'Nie. Współdzielić konta nie mogą:
# * posiadacze kont Firma (po przekształceniu konta zwykłego na kont...', score: 19.575956), Document(id=785, content: 'Program Numizmatyka profesjonalna dedykujemy największym Sprzedającym w kategorii Numizmatyka, którz...', score: 16.0045), Document(id=798, content: 'Propozycja pożyczki będzie dostępna, jeśli spełniasz poniższe kryteria:
# * masz aktywne konto firmowe...', score: 15.967678), Document(id=654, content: 'Konto zwykłe (prywatne) może być używane jedynie przez jego właściciela - osobę, która je zarejestro...', score: 15.197505), Document(id=529, content: 'Jako posiadacza konta Junior, dotyczy Cię limit 50 zł na wystawianie przedmiotów. Oznacza to, że jeś...', score: 14.354121), Document(id=528, content: 'Na Allegro zabroniona jest sprzedaż katalogów wysyłkowych i sprzedaży bezpośredniej, które umożliwia...', score: 13.882865), Document(id=144, content: 'Rachunek bieżący sprawdzisz w zakładce Moje Allegro > Moje konto > Rachunki: Historia.
# Masz do wybor...', score: 13.8502655)]}}
# {'retriever': {'documents': [Document(id=568, content: 'Nazwisko panieńskie matki będzie Ci potrzebne, jeśli zapomnisz hasła do konta Allegro.
# Podasz je po ...', score: 18.467827), Document(id=212, content: 'Dodaj nazwisko panieńskie swojej matki do ustawień konta. Dzięki temu nie stracisz do niego dostępu,...', score: 17.085682), Document(id=390, content: 'Odzyskiwanie hasła za pomocą "Nie pamiętasz hasła?"
# Kliknij w link [Nie pamiętasz hasła?]. Wpisz adr...', score: 16.29675), Document(id=411, content: '1. Przejdź do zakładki Dane konta Allegro.
# 2. W części Moje dane pole Imię i nazwisko jest nieaktywn...', score: 7.820434), Document(id=639, content: 'Na Twoją prośbę ograniczymy przetwarzanie danych tylko do ich przechowywania. Przestaniemy wtedy wyk...', score: 5.8603373), Document(id=61, content: 'Możesz zmienić imię lub nazwisko w ustawieniach konta zwykłego, jeśli:
# *     błędnie je wpiszesz pod...', score: 5.808367), Document(id=66, content: 'Manipulacja słowami kluczowymi ma miejsce wtedy, gdy Sprzedający nieprawidłowo wykorzystuje pewne wy...', score: 5.502818), Document(id=787, content: '* w licytacjach,
# * gdy wystawiasz oferty w kategoriach, w których raty nie są dostępne,
# * jeśli posi...', score: 4.9048357), Document(id=780, content: '* Kupujący częściej zajrzą do Twoich ofert, kiedy będą szukać części pasujących do ich modelu samoch...', score: 4.750334), Document(id=651, content: 'W niektórych przypadkach, po rejestracji konta firmowego i jego aktywacji, prosimy przedsiębiorców o...', score: 4.670556)]}}

# %%
preds.to_csv(os.path.join(dataset_path, 'submission.tsv'), sep='\t', index=False)
